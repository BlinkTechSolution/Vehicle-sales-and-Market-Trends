# %%
# Importation of libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
plt.style.use('ggplot')

# %%
# Loading of dataset
df=pd.read_csv("1726325075237_239427e180/car_prices.csv")
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# print out information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
# Print out the number of empty cells in each column
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
# Get the  frequency of the unique data in the transmission column and print
Unique_counts = df['transmission'].value_counts()
print("Frequency of unique values in Transmission column:")
print(Unique_counts)
# Out:
# Frequency of unique values in Transmission column:
# automatic    475915
# manual        17544
# sedan            15
# Sedan            11
# Name: transmission, dtype: int64

# %%
# Fill transmission empty cells with the highest occuring value
df['transmission'] = df['transmission'].fillna('automatic')

# %%
# Get the  frequency of the unique data in the Vin column and print
Unique_counts = df['vin'].value_counts()
print("Frequency of unique values in Vin column:")
print(Unique_counts)
# Out:
# Frequency of unique values in Vin column:
# automatic            22
# wbanv13588cz57827     5
# 5uxfe43579l274932     4
# trusc28n241022003     4
# wddgf56x78f009940     4
#                      ..
# 1p3ew65g7yv603989     1
# 4t1bf28b1yu016829     1
# jtdbt1231y0082703     1
# jtddr32t8y0063746     1
# 1ftfw1et2eke87277     1
# Name: vin, Length: 550297, dtype: int64

# %%
# Fill vin empty cells with the highest occuring value
df['vin'] = df['vin'].fillna('automatic')

# %%
# Get the  frequency of the unique data in the condition column and print
Unique_counts = df['condition'].value_counts()
print("Frequency of unique values in condition column:")
print(Unique_counts)
# Out:
# Frequency of unique values in condition column:
# 19.0    42281
# 35.0    26750
# 37.0    25938
# 44.0    25514
# 43.0    24937
# 42.0    24328
# 36.0    23144
# 41.0    23073
# 2.0     20790
# 4.0     19922
# 39.0    19920
# 28.0    19178
# 29.0    18928
# 38.0    18723
# 34.0    17398
# 27.0    16351
# 49.0    13099
# 48.0    12712
# 46.0    12634
# 25.0    12561
# 45.0    12313
# 26.0    11912
# 47.0    11363
# 5.0     11222
# 3.0     10803
# 33.0    10619
# 32.0     9962
# 24.0     9326
# 31.0     9222
# 21.0     9199
# 23.0     8188
# 1.0      7364
# 22.0     6057
# 18.0      323
# 17.0      243
# 16.0      178
# 15.0      144
# 14.0      134
# 12.0       95
# 11.0       87
# 13.0       82
# Name: condition, dtype: int64

# %%
# Fill condition empty cells with the highest occuring value
df['condition'] = df['condition'].fillna('19.0')

# %%
# Get the  frequency of the unique data in the odometer column
Unique_counts = df['odometer'].value_counts()
print("Frequency of unique values in odometer column:")
print(Unique_counts)
# Out:
# Frequency of unique values in odometer column:
# 1.0         1318
# 999999.0      72
# 10.0          29
# 21587.0       21
# 29137.0       18
#             ...
# 84791.0        1
# 184061.0       1
# 113144.0       1
# 201099.0       1
# 262065.0       1
# Name: odometer, Length: 172278, dtype: int64

# %%
# Fill odometer empty cells with the highest occuring value and print
df['odometer'] = df['odometer'].fillna('1.0')

# %%
# Get the  frequency of the unique data in the Color column
Unique_counts = df['color'].value_counts()
print("Frequency of unique values in color column:")
print(Unique_counts)
# Out:
# Frequency of unique values in color column:
# black        110970
# white        106673
# silver        83389
# gray          82857
# blue          51139
# red           43569
# —             24685
# green         11382
# gold          11342
# beige          9222
# burgundy       8972
# brown          6717
# orange         2078
# purple         1561
# off-white      1449
# yellow         1285
# charcoal        479
# turquoise       236
# pink             42
# lime             15
# 9562              1
# 2846              1
# 18561             1
# 18384             1
# 5705              1
# 2817              1
# 6158              1
# 721               1
# 20627             1
# 20379             1
# 9837              1
# 9887              1
# 2172              1
# 339               1
# 6864              1
# 2711              1
# 11034             1
# 16633             1
# 6388              1
# 15719             1
# 12655             1
# 14872             1
# 1167              1
# ...

# %%
# Fill color empty cells with the highest occuring value
most_frequent = df['color'].mode()[0]
df['color'].fillna(most_frequent, inplace=True)

# %%
# Get the  frequency of the unique data in the interior column and print
Unique_counts = df['interior'].value_counts()
print("Frequency of unique values in interior column:")
print(Unique_counts)
# Out:
# Frequency of unique values in interior column:
# black        244329
# gray         178581
# beige         59758
# tan           44093
# —             17077
# brown          8640
# red            1363
# blue           1143
# silver         1104
# off-white       480
# purple          339
# gold            324
# white           256
# green           245
# burgundy        191
# orange          145
# yellow           20
# Name: interior, dtype: int64

# %%
# Fill interior empty cells with the highest occuring value
most_frequent = df['interior'].mode()[0]
df['interior'].fillna(most_frequent, inplace=True)

# %%
# Get the  frequency of the unique data in the Car column
Unique_counts = df['mmr'].value_counts()
print("Frequency of unique values in mmr column:")
print(Unique_counts)
# Out:
# Frequency of unique values in mmr column:
# 12500.0     1761
# 11600.0     1751
# 11650.0     1746
# 12150.0     1722
# 11850.0     1717
#             ...
# 172000.0       1
# 134000.0       1
# 113000.0       1
# 154000.0       1
# 164000.0       1
# Name: mmr, Length: 1101, dtype: int64

# %%
# Fill mmr empty cells with the highest occuring value
most_frequent = df['mmr'].mode()[0]
df['mmr'].fillna(most_frequent, inplace=True)

# %%
# Get the  frequency of the unique data in the selling price column and print
Unique_counts = df['sellingprice'].value_counts()
print("Frequency of unique values in sellingprice column:")
print(Unique_counts)
# Out:
# Frequency of unique values in sellingprice column:
# 11000.0     4453
# 12000.0     4450
# 13000.0     4334
# 10000.0     4029
# 14000.0     3899
#             ...
# 28350.0        1
# 30201.0        1
# 131500.0       1
# 31550.0        1
# 27840.0        1
# Name: sellingprice, Length: 1887, dtype: int64

# %%
# Fill sellingprice empty cells with the highest occuring value
most_frequent = df['sellingprice'].mode()[0]
df['sellingprice'].fillna(most_frequent, inplace=True)

# %%
# Get the  frequency of the unique data in the saledate column
Unique_counts = df['saledate'].value_counts()
print("Frequency of unique values in saledate column:")
print(Unique_counts)
# Out:
# Frequency of unique values in saledate column:
# Tue Feb 10 2015 01:30:00 GMT-0800 (PST)    5334
# Tue Feb 17 2015 01:30:00 GMT-0800 (PST)    5016
# Tue Jan 27 2015 01:30:00 GMT-0800 (PST)    4902
# Tue Jan 20 2015 01:30:00 GMT-0800 (PST)    4731
# Tue Mar 03 2015 01:30:00 GMT-0800 (PST)    4653
#                                            ...
# Thu Feb 05 2015 05:10:00 GMT-0800 (PST)       1
# Thu Jan 02 2014 09:30:00 GMT-0800 (PST)       1
# Tue Apr 28 2015 05:50:00 GMT-0700 (PDT)       1
# Wed Jan 21 2015 05:45:00 GMT-0800 (PST)       1
# Wed Jul 08 2015 09:45:00 GMT-0700 (PDT)       1
# Name: saledate, Length: 3766, dtype: int64

# %%
# Fill transmission empty cells with the highest occuring value and convert to datetime data format
df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce', utc=True)
df['saledate'].fillna(method='ffill', inplace=True) 
df['saledate'] = pd.to_datetime(df['saledate'], utc=True)

# %%
# Print information about the pre-processed dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  558837 non-null  object
#  6   vin           558837 non-null  object
#  7   state         558837 non-null  object
#  8   condition     558837 non-null  object
#  9   odometer      558837 non-null  object
#  10  color         558837 non-null  object
#  11  interior      558837 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  float64
#  14  sellingprice  558837 non-null  float64
#  15  saledate      558837 non-null  datetime64[ns, UTC]
# ...

# %%
# Get the  frequency of the unique data in the make column and print
Unique_counts = df['make'].unique()
number_Unique_counts = df['make'].nunique()
print("Numbers of unique counts", number_Unique_counts)
print(Unique_counts)
# Out:
# Numbers of unique counts 96
# ['Kia' 'BMW' 'Volvo' 'Nissan' 'Chevrolet' 'Audi' 'Ford' 'Hyundai' 'Buick'
#  'Cadillac' 'Acura' 'Lexus' 'Infiniti' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Mazda' 'MINI' 'Land Rover' 'Lincoln' 'lincoln' 'Jaguar' 'Volkswagen'
#  'Toyota' 'Subaru' 'Scion' 'Porsche' nan 'bmw' 'Dodge' 'FIAT' 'Chrysler'
#  'ford' 'Ferrari' 'Honda' 'GMC' 'mitsubishi' 'Ram' 'smart' 'chevrolet'
#  'Bentley' 'chrysler' 'pontiac' 'Pontiac' 'Saturn' 'Maserati' 'Mercury'
#  'HUMMER' 'landrover' 'cadillac' 'land rover' 'mercedes' 'mazda' 'toyota'
#  'lexus' 'gmc truck' 'honda' 'nissan' 'porsche' 'Saab' 'Suzuki' 'dodge'
#  'subaru' 'Oldsmobile' 'oldsmobile' 'hyundai' 'jeep' 'Isuzu' 'dodge tk'
#  'Geo' 'acura' 'volkswagen' 'suzuki' 'kia' 'audi' 'Rolls-Royce' 'gmc'
#  'maserati' 'mazda tk' 'mercury' 'buick' 'hyundai tk' 'mercedes-b' 'vw'
#  'Daewoo' 'chev truck' 'ford tk' 'plymouth' 'Plymouth' 'ford truck'
#  'Tesla' 'airstream' 'dot' 'Aston Martin' 'Fisker' 'Lamborghini' 'Lotus']

# %%
#A function to remove duplicates of vehicle manufacturer
def sentence_case(text):
    if pd.isnull(text):  # Check for NaN values
        return text
    text = str(text).lower()  # Convert the text to lowercase
    return text.capitalize()  # Capitalize only the first letter

# %%
# Application of the function
df['make'] = df['make'].apply(sentence_case)

# %%
# Get the  frequency of the unique data in the new make column
Unique_counts = df['make'].unique()
number_Unique_counts = df['make'].nunique()
print("Numbers of unique counts", number_Unique_counts)
print(Unique_counts)
# Out:
# Numbers of unique counts 66
# ['Kia' 'Bmw' 'Volvo' 'Nissan' 'Chevrolet' 'Audi' 'Ford' 'Hyundai' 'Buick'
#  'Cadillac' 'Acura' 'Lexus' 'Infiniti' 'Jeep' 'Mercedes-benz' 'Mitsubishi'
#  'Mazda' 'Mini' 'Land rover' 'Lincoln' 'Jaguar' 'Volkswagen' 'Toyota'
#  'Subaru' 'Scion' 'Porsche' nan 'Dodge' 'Fiat' 'Chrysler' 'Ferrari'
#  'Honda' 'Gmc' 'Ram' 'Smart' 'Bentley' 'Pontiac' 'Saturn' 'Maserati'
#  'Mercury' 'Hummer' 'Landrover' 'Mercedes' 'Gmc truck' 'Saab' 'Suzuki'
#  'Oldsmobile' 'Isuzu' 'Dodge tk' 'Geo' 'Rolls-royce' 'Mazda tk'
#  'Hyundai tk' 'Mercedes-b' 'Vw' 'Daewoo' 'Chev truck' 'Ford tk' 'Plymouth'
#  'Ford truck' 'Tesla' 'Airstream' 'Dot' 'Aston martin' 'Fisker'
#  'Lamborghini' 'Lotus']

# %%
# To remove duplicates in the make dataset
mapping = {
    'Mercedes-benz': 'Mercedes',
    'Mercedes-b': 'Mercedes',
    'Mazda tk': 'Mazda',
    'Hyundai tk': 'Hyundai',
    'Ford tk': 'Ford',
    'Dodge tk': 'Dodge',
    'Chev truck': 'Chevrolet',
    'Ford truck' : 'Ford',
    'Gmc truck' : 'Gmc',
    'Vw' : 'Volkswagen'
}
df['make'] = df['make'].replace(mapping)

# %%
# Get the  frequency of the unique data in the model column
Unique_counts = df['model'].unique()
number_Unique_counts = df['model'].nunique()
print("Numbers of unique counts", number_Unique_counts)
print(Unique_counts)
# Out:
# Numbers of unique counts 973
# ['Sorento' '3 Series' 'S60' '6 Series Gran Coupe' 'Altima' 'M5' 'Cruze'
#  'A4' 'Camaro' 'A6' 'Optima' 'Fusion' 'Sonata' 'Q5' '6 Series' 'Impala'
#  '5 Series' 'A3' 'XC70' 'X5' 'SQ5' 'S5' 'Verano' 'Suburban' 'ELR' 'V60'
#  'X6' 'ILX' 'K900' 'Malibu' 'RX 350' 'Versa' 'Elantra' 'Versa Note' 'A8'
#  'X1' nan 'Enclave' 'TTS' '4 Series' 'Silverado 2500HD' 'MDX'
#  'Silverado 1500' 'SRX' 'G Coupe' 'G Sedan' 'FX' 'Santa Fe' 'Genesis'
#  'Equus' 'Sonata Hybrid' 'Accent' 'Veloster' 'Elantra Coupe' 'Azera'
#  'Tucson' 'Genesis Coupe' 'Wrangler' 'S-Class' 'GS 350' 'Outlander'
#  'C-Class' 'Mazda2' 'Rio' 'M' '370Z' 'Soul' 'Outlander Sport' 'SLK-Class'
#  'ES 350' 'E-Class' 'Mazda3' 'Cooper Clubman' 'Cooper' 'CX-9' 'Forte'
#  'Compass' 'JX' 'RX 450h' 'LR4' 'Mazda5' 'Range Rover Evoque' 'LS 460'
#  'GLK-Class' 'Sportage' 'Grand Cherokee' 'MKX' 'mkt' 'XF' 'GL-Class'
#  'M-Class' 'Cooper Countryman' 'Lancer' 'Range Rover Sport' 'Passat'
# ...

# %%
# Function to remove duplicates from the model column
def sentence_case(text):
    if pd.isnull(text):  # Check for NaN values
        return text
    text = str(text).lower()  # Convert the text to lowercase
    return text.capitalize()  # Capitalize only the first letter
df['model'] = df['model'].apply(sentence_case)

# %%
# Get the  frequency of the unique data in the new model column
Unique_counts = df['model'].unique()
number_Unique_counts = df['model'].nunique()
print("Numbers of unique counts", number_Unique_counts)
print(Unique_counts)
# Out:
# Numbers of unique counts 851
# ['Sorento' '3 series' 'S60' '6 series gran coupe' 'Altima' 'M5' 'Cruze'
#  'A4' 'Camaro' 'A6' 'Optima' 'Fusion' 'Sonata' 'Q5' '6 series' 'Impala'
#  '5 series' 'A3' 'Xc70' 'X5' 'Sq5' 'S5' 'Verano' 'Suburban' 'Elr' 'V60'
#  'X6' 'Ilx' 'K900' 'Malibu' 'Rx 350' 'Versa' 'Elantra' 'Versa note' 'A8'
#  'X1' nan 'Enclave' 'Tts' '4 series' 'Silverado 2500hd' 'Mdx'
#  'Silverado 1500' 'Srx' 'G coupe' 'G sedan' 'Fx' 'Santa fe' 'Genesis'
#  'Equus' 'Sonata hybrid' 'Accent' 'Veloster' 'Elantra coupe' 'Azera'
#  'Tucson' 'Genesis coupe' 'Wrangler' 'S-class' 'Gs 350' 'Outlander'
#  'C-class' 'Mazda2' 'Rio' 'M' '370z' 'Soul' 'Outlander sport' 'Slk-class'
#  'Es 350' 'E-class' 'Mazda3' 'Cooper clubman' 'Cooper' 'Cx-9' 'Forte'
#  'Compass' 'Jx' 'Rx 450h' 'Lr4' 'Mazda5' 'Range rover evoque' 'Ls 460'
#  'Glk-class' 'Sportage' 'Grand cherokee' 'Mkx' 'Mkt' 'Xf' 'Gl-class'
#  'M-class' 'Cooper countryman' 'Lancer' 'Range rover sport' 'Passat'
# ...

# %%
# Create a column for the vehicles manufacturer number
df['Vin_maker'] = df['vin'].str[:4]

# %%
# Create a dictionary of manufacturer name with their vin numbers
data = df.groupby('make')['Vin_maker'].unique()
data.to_dict()
# Out:
# {'Acura': array(['19vd', '5fry', 'jh4c', '19uu', '5j8t', '2hny', 'jh4d', 'jh4k',
#         '2hhe', '19uy', 'jh4u'], dtype=object),
#  'Airstream': array(['wd3p'], dtype=object),
#  'Aston martin': array(['scfb', 'scfa', 'scfh'], dtype=object),
#  'Audi': array(['wauf', 'wauh', 'wa1l', 'waua', 'wa1c', 'wauc', 'waur', 'trub',
#         'waug', 'wauk', 'wauy', 'waul', 'waub', 'wuaa', 'wa1d', 'wauv',
#         'waue', 'wauj', 'waus', 'wa1a', 'trud', 'waum', 'waud', 'wuar',
#         'waup', 'wa1y', 'trut', 'waux', 'wa19', 'wuaw', 'waun', 'wuac',
#         'wa1w', 'wau3', 'wauw', 'wa1k', 'truv', 'trur', 'wa1b', 'wa1e',
#         'trus', 'wuap', 'truw', 'truu', 'wauz', 'wa1u', 'wau2', 'tru4',
#         'wuav', 'trum', 'wa1v', 'wuad', 'trua', 'wuae', 'wa1t', 'wuat',
#         'wa1m', 'truh', 'truk', 'wuag', 'wuas', 'wau4'], dtype=object),
#  'Bentley': array(['scbc', 'scbb', 'scbg', 'scbf', 'scbd', 'scbe'], dtype=object),
# ...

# %%
# Function to replace the missing values in the make column.
def maker_vectorized(df, data):
    # Create a function that searches for the key in the dictionary
    def find_maker(vin_value):
        for key, value in data.items():
            if str(vin_value) in value:  # Search for the vin_value in the list
                return key
            
        return None  # Default value if no match is found

    # Apply the function to each row in the 'Vin_maker' column
    df['make'] = df['Vin_maker'].apply(find_maker)
    
    return df['make']

# %%
# Application of the created function
df['make'] = maker_vectorized(df, data)

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     Bmw             3 series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     Bmw  6 series gran coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     Bmw                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state condition odometer   color  \
# 0         automatic  5xyktca69fg566472    ca       5.0  16639.0   white
# ...

# %%
# Print columns with their respective number of missing instances
df.isnull().sum()
# Out:
# year                0
# make               98
# model           10399
# trim            10651
# body            13195
# transmission        0
# vin                 0
# state               0
# condition           0
# odometer            0
# color               0
# interior            0
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# Vin_maker           0
# dtype: int64

# %%
# Replace the remaining 98 empty cells in the make column with the highest occuring value
most_frequent = df['make'].mode()[0]
df['make'].fillna(most_frequent, inplace=True)

# %%
# Create a dictionary of model name with their vin numbers
df['model_type'] = df['vin'].str[3:7]

# %%
# print first five rows
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    Bmw             3 series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    Bmw  6 series gran coupe        650i  Sedan    automatic
#
#                  vin state condition odometer  color interior  \
# 0  5xyktca69fg566472    ca       5.0  16639.0  white    black
# 1  5xyktca69fg561319    ca       5.0   9393.0  white    beige
# 2  wba3c1c51ek116351    ca      45.0   1331.0   gray    black
# 3  yv1612tb4f1310987    ca      41.0  14282.0  white    black
# 4  wba6b2c57ed129731    ca      43.0   2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
# Create a dictionary of model name with their vin numbers
model_data = df.groupby(['model'])['model_type'].unique()
model_data = model_data.to_dict()

# %%
# Dictionatary of model name and their respective vin numbers
model_data
# Out:
# {'1': array(['ur9c'], dtype=object),
#  '1 series': array(['uc9c', 'un1c', 'up9c', 'un93', 'un13', 'ul7c', 'uc7c', 'up7c',
#         'up93', 'uc73', 'ul73', 'up73', 'un9c', 'un7c'], dtype=object),
#  '1500': array(['jd6c', 'jd6a', 'rd6g', 'rb1g', 'rv1g', 'ec16', 'ec14', 'ec19',
#         'rr6g', 'rr7g', 'ek14', 'rd7k', 'rd6f', 'rd7g', 'rd7f', 'rd7n',
#         'rd7h', 'jd7e', 'rd7l', 'rd7p', 'rd6p', 'rr7m', 'rb1c', 'rv1c',
#         'jb1e', 'ec13', 'ek13', 'ek19', 'rr7f', 'jr7d', 'rr6f', 'rr6n',
#         'rr7n', 'rr7k', 'jr6c', 'rr7l', 'rr7h', 'rr7p', 'rr6l', 'rr6k',
#         'jr6a', 'rr7t', 'rd6k', 'rr7j', 'rr6s', 'rd6l', 'fk16', 'rr6v',
#         'rd7m', 'jr7a', 'rr6p', 'rr7v', 'jr6d', 'rr6w', 'jd6d', 'rr7s',
#         'rr6m', 'rr6h', 'rd6n', 'rd6h', 'rr6u', 'rr7u', 'jd7a', 'rr7w',
#         'jd6e', 'rd7j', 'rd6m', 'jr6e', 'rd6j', 'jd7b', 'jr6b'],
#        dtype=object),
#  '190-class': array(['da28'], dtype=object),
#  '2 series': array(['1f5c', '1j7c'], dtype=object),
# ...

# %%
# Function to replace the missing cells in the model column.
def model_vectorized(df, data):
    # Create a function that searches for the key in the dictionary
    def find_maker(vin_value):
        for key, value in model_data.items():
            if str(vin_value) in value:  # Search for the vin_value in the list
                return key
            
        return None  # Default value if no match is found

    # Apply the function to each row in the 'Vin_maker' column
    df['model'] = df['model_type'].apply(find_maker)
    
    return df['model']

# %%
# Aplication of the created function.
df['model'] = model_vectorized(df, model_data)

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     Bmw             3 series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     Bmw  6 series gran coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     Bmw                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state condition odometer   color  \
# 0         automatic  5xyktca69fg566472    ca       5.0  16639.0   white
# ...

# %%
# Print columns with their respective number of missing instances
df.isnull().sum()
# Out:
# year                0
# make                0
# model             346
# trim            10651
# body            13195
# transmission        0
# vin                 0
# state               0
# condition           0
# odometer            0
# color               0
# interior            0
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# Vin_maker           0
# model_type          0
# dtype: int64

# %%
# Replace the remaining empty cell in the model column with the highest occuring value
most_frequent = df['model'].mode()[0]
df['model'].fillna(most_frequent, inplace=True)

# %%
# Replace the empty cell in the trim column with the highest occuring value
most_frequent = df['trim'].mode()[0]
df['trim'].fillna(most_frequent, inplace=True)

# %%
# Replace the empty cells in the body column with the highest occuring value
most_frequent = df['body'].mode()[0]
df['body'].fillna(most_frequent, inplace=True)

# %%
# Print out the outcome of the data preprocessing
print("Number of missing instance in each of the column")
df.isnull().sum()
# Out:
# Number of missing instance in each of the column
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# Vin_maker       0
# model_type      0
# dtype: int64

# %% [markdown]
# # Identify trends in vehicle sales over time.

# %%
# Create a column for the saledate (years) 
df['sale_year'] = df['saledate'].dt.year

# %%
# Print out sales that took place in year 2014
df1= df[df['sale_year']==2014]
df1
# Out:
#        year      make                model          trim       body  \
# 0      2015       Kia              Sorento            LX        SUV
# 1      2015       Kia              Sorento            LX        SUV
# 4      2014       Bmw  6 series gran coupe          650i      Sedan
# 5      2015    Nissan               Altima         2.5 S      Sedan
# 6      2014       Bmw                   M5          Base      Sedan
# ...     ...       ...                  ...           ...        ...
# 75655  2011      Mini    Cooper countryman             S      Wagon
# 75683  2011  Mercedes             Gl-class  GL450 4MATIC        SUV
# 75695  2011     Mazda               Mazda6       i Sport      Sedan
# 75712  2011     Mazda               Mazda3         Sport  Hatchback
# 76042  2012       Gmc               Acadia         SLT-1        SUV
#
#       transmission                vin state condition odometer   color  \
# 0        automatic  5xyktca69fg566472    ca       5.0  16639.0   white
# ...

# %%
# Arrange the saledate of 2014 for analysis 
df1.set_index('saledate', inplace=True)

# Resample data by month and sum the sales
monthly_sales = df1['sellingprice'].resample('M').sum()

# Check the aggregated monthly sales data
print(monthly_sales)
# Out:
# saledate
# 2014-01-31 00:00:00+00:00      3204525.0
# 2014-02-28 00:00:00+00:00        10500.0
# 2014-03-31 00:00:00+00:00            0.0
# 2014-04-30 00:00:00+00:00            0.0
# 2014-05-31 00:00:00+00:00            0.0
# 2014-06-30 00:00:00+00:00            0.0
# 2014-07-31 00:00:00+00:00            0.0
# 2014-08-31 00:00:00+00:00            0.0
# 2014-09-30 00:00:00+00:00            0.0
# 2014-10-31 00:00:00+00:00            0.0
# 2014-11-30 00:00:00+00:00            0.0
# 2014-12-31 00:00:00+00:00    604434205.0
# Freq: M, Name: sellingprice, dtype: float64

# %%
# Plot graph of number of vehicle sales for year 2014
plt.figure(figsize=(10,6))
plt.plot(monthly_sales.index, monthly_sales, marker='o')
plt.title('Vehicle Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Vehicles Sold')
plt.grid(True)
plt.show()

# %%
# Print out sales that took place in year 2015
df2 = df[df['sale_year']==2015]
df2
# Out:
#         year       make     model         trim         body transmission  \
# 2       2014        Bmw  3 series   328i SULEV        Sedan    automatic
# 3       2015      Volvo       S60           T5        Sedan    automatic
# 9       2014  Chevrolet    Camaro           LT  Convertible    automatic
# 12      2015       Ford    Fusion           SE        Sedan    automatic
# 20      2015  Chevrolet    Impala          LTZ        Sedan    automatic
# ...      ...        ...       ...          ...          ...          ...
# 558832  2015        Kia      K900       Luxury        Sedan    automatic
# 558833  2012        Ram      2500  Power Wagon     Crew Cab    automatic
# 558834  2012        Bmw        X5    xDrive35d          SUV    automatic
# 558835  2015     Nissan    Altima        2.5 S        sedan    automatic
# 558836  2014       Ford     F-150          XLT    SuperCrew    automatic
#
#                       vin state condition odometer   color interior  \
# ...

# %%
# Arrange the saledate for 2015 for analysis
df2.set_index('saledate', inplace=True)

# Resample data by month and sum the sales
monthly_sales = df2['sellingprice'].resample('M').sum()

# Check the aggregated monthly sales data
print(monthly_sales)
# Out:
# saledate
# 2015-01-31 00:00:00+00:00    1.868476e+09
# 2015-02-28 00:00:00+00:00    2.218863e+09
# 2015-03-31 00:00:00+00:00    6.228744e+08
# 2015-04-30 00:00:00+00:00    1.459504e+07
# 2015-05-31 00:00:00+00:00    7.598239e+08
# 2015-06-30 00:00:00+00:00    1.492787e+09
# 2015-07-31 00:00:00+00:00    2.143081e+07
# Freq: M, Name: sellingprice, dtype: float64

# %%
# Plot graph of number of vehicle sales for year 2015.
plt.figure(figsize=(10,6))
plt.plot(monthly_sales.index, monthly_sales, marker='o')
plt.title('Vehicle Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Vehicles Sold')
plt.grid(True)
plt.show()

# %%
# Arrange the saledate over-time for analysis
df3 = df.copy()
df3.set_index('saledate', inplace=True)

# Resample data by month and sum the sales
monthly_sales = df3['sellingprice'].resample('M').sum()

# Check the aggregated monthly sales data
print(monthly_sales)
# Out:
# saledate
# 2014-01-31 00:00:00+00:00    3.204525e+06
# 2014-02-28 00:00:00+00:00    1.050000e+04
# 2014-03-31 00:00:00+00:00    0.000000e+00
# 2014-04-30 00:00:00+00:00    0.000000e+00
# 2014-05-31 00:00:00+00:00    0.000000e+00
# 2014-06-30 00:00:00+00:00    0.000000e+00
# 2014-07-31 00:00:00+00:00    0.000000e+00
# 2014-08-31 00:00:00+00:00    0.000000e+00
# 2014-09-30 00:00:00+00:00    0.000000e+00
# 2014-10-31 00:00:00+00:00    0.000000e+00
# 2014-11-30 00:00:00+00:00    0.000000e+00
# 2014-12-31 00:00:00+00:00    6.044342e+08
# 2015-01-31 00:00:00+00:00    1.868476e+09
# 2015-02-28 00:00:00+00:00    2.218863e+09
# 2015-03-31 00:00:00+00:00    6.228744e+08
# 2015-04-30 00:00:00+00:00    1.459504e+07
# 2015-05-31 00:00:00+00:00    7.598239e+08
# 2015-06-30 00:00:00+00:00    1.492787e+09
# 2015-07-31 00:00:00+00:00    2.143081e+07
# Freq: M, Name: sellingprice, dtype: float64

# %%
# Plot graph of number of vehicle sales over time.
plt.figure(figsize=(10,6))
plt.plot(monthly_sales.index, monthly_sales, marker='o')
plt.title('Vehicle Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Vehicles Sold')
plt.grid(True)
plt.show()

# %% [markdown]
# # Analyze the impact of vehicle condition and mileage on selling prices.

# %%
# print out dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          558837 non-null  object
#  2   model         558837 non-null  object
#  3   trim          558837 non-null  object
#  4   body          558837 non-null  object
#  5   transmission  558837 non-null  object
#  6   vin           558837 non-null  object
#  7   state         558837 non-null  object
#  8   condition     558837 non-null  object
#  9   odometer      558837 non-null  object
#  10  color         558837 non-null  object
#  11  interior      558837 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  float64
#  14  sellingprice  558837 non-null  float64
#  15  saledate      558837 non-null  datetime64[ns, UTC]
#  16  Vin_maker     558837 non-null  object
# ...

# %%
# Convert condition and odometer from object to float data type.
df['condition'] = df['condition'].astype('float64')
df['odometer'] = df['odometer'].astype('float64')

# %%
df.describe().T
# Out:
#                  count          mean           std     min      25%      50%  \
# year          558837.0   2010.038927      3.966864  1982.0   2007.0   2012.0
# condition     558837.0     30.425482     13.366270     1.0     22.0     34.0
# odometer      558837.0  68308.526066  53401.401863     1.0  28359.0  52245.0
# mmr           558837.0  13769.291180   9679.643716    25.0   7100.0  12250.0
# sellingprice  558837.0  13611.302736   9749.404460     1.0   6900.0  12100.0
# sale_year     558837.0   2014.903859      0.294784  2014.0   2015.0   2015.0
#
#                   75%       max
# year           2013.0    2015.0
# condition        41.0      49.0
# odometer      99103.0  999999.0
# mmr           18300.0  182000.0
# sellingprice  18200.0  230000.0
# sale_year      2015.0    2015.0

# %%
# Scatter plot for mileage vs selling price
plt.figure(figsize=(10, 5)) 
sns.scatterplot(x=df['odometer'], y=df['sellingprice'] , data=df)
plt.title("Mileage vs Selling Price")
plt.show()

# %%
# plot Box plot of vehicle condition and selling orice
plt.figure(figsize=(10, 5)) 
# Box plot for condition vs selling price
sns.boxplot(x=df['condition'], y=df['sellingprice'], data=df)
plt.xticks(rotation=90)
plt.title("Vehicle Condition vs Selling Price")
plt.show()

# %%
# Create a dataframe for odometer, condition, and sellingprice for correlation purpose
df3 = df[['odometer', 'condition', 'sellingprice']]

# %%
# Compute the correlation value for the three features
correlation_matrix = df3.corr()['sellingprice']
print(correlation_matrix)
# Out:
# odometer       -0.582030
# condition       0.329332
# sellingprice    1.000000
# Name: sellingprice, dtype: float64

# %%
# Plot a correlation matrix
corr_matrix = df3.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# # Understand the relationship between MMR values and actual selling prices.

# %%
# Scatter plot for MMR  vs selling price
plt.figure(figsize=(10, 5)) 
sns.scatterplot(x=df['mmr'], y=df['sellingprice'] , data=df)
plt.title("MMR vs Selling Price")
plt.show()

# %%
# Calculate Pearson correlation
correlation = df['mmr'].corr(df['sellingprice'])
print("Pearson Correlation:", correlation)
# Out:
# Pearson Correlation: 0.9836341155771343

# %%
# Plot correlation matrix for mmr and selling price
df4 = df[['mmr', 'sellingprice']]
corr_matrix = df4.corr()

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# # Determine the most popular vehicle makes and models.

# %%
#print the dataset
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     Bmw             3 series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     Bmw  6 series gran coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     Bmw                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# Create a copy of the dataset
df4 = df.copy()

# %%
# Plot bar chart for vehicle manufacturesr against the number of sales
make_counts = df4['make'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=make_counts.index[:], y=make_counts.values[:], palette='coolwarm')
plt.xticks(rotation=90)
plt.title('Most Popular Vehicle Makes')
plt.xlabel('Vehicle Make')
plt.ylabel('Count')
plt.show()

# %%
# Group by 'make' and 'model' and count occurrences, sort it and display the most popular vehicle model
make_model_counts = df4.groupby(['make', 'model']).size().reset_index(name='count')
most_popular_models = make_model_counts.sort_values(by='count', ascending=False)

most_popular_models = make_model_counts.sort_values(by='count', ascending=False)

print("\nMost Popular Vehicle Models:\n",most_popular_models)
# Out:
# Most Popular Vehicle Models:
#             make          model  count
# 788      Nissan         Altima  19349
# 373        Ford          F-150  14812
# 387        Ford         Fusion  13044
# 955      Toyota          Camry  12894
# 360        Ford         Escape  12050
# ..          ...            ...    ...
# 463       Honda  Civic del sol      1
# 56          Bmw              1      1
# 43         Audi             S7      1
# 322     Ferrari            360      1
# 813  Oldsmobile         Altima      1
#
# [1048 rows x 3 columns]

# %%
# Visualization of Most Popular Vehicle Models 
plt.figure(figsize=(12, 6))
sns.barplot(x='model', y='count', hue='make', data=most_popular_models.head(10), palette='viridis')
plt.title('Top 10 Most Popular Vehicle Models')
plt.xlabel('Vehicle Model')
plt.ylabel('Count')
plt.show()
